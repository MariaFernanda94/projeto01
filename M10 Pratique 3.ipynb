# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_renda = pd.read_csv('Profissão Cientista de Dados M10 A1.csv')
df_renda['data_ref'] = pd.to_datetime(df_renda['data_ref'])

plt.figure(figsize=(12, 6))
sns.countplot(x='data_ref', hue='posse_de_veiculo', data=df_renda)
plt.title('Distribuição de Posse de Veículo ao longo do tempo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
plt.figure(figsize=(12, 6))
sns.pointplot(x='data_ref', y='renda', hue='posse_de_veiculo', 
              data=df_renda, dodge=True, errorbar=('ci', 95))
plt.title('Estabilidade da Renda Média por Posse de Veículo')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12, 6))
sns.pointplot(x='data_ref', y='renda', hue='posse_de_imovel', 
              data=df_renda, dodge=True, errorbar=('ci', 95))
plt.title('Estabilidade da Renda Média por Posse de Imóvel')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Na minha análise sobre o resultado, notei que mesmo com a mudança no código, o visual permanece o mesmo. Identifiquei que as variáveis continuam estáveis ao longo dos meses, o que me dá confiança para utilizá-las na modelagem. Percebi que essa estabilidade é um ótimo sinal, pois indica que os padrões que eu encontrar hoje não são flutuações temporárias, mas sim comportamentos consistentes do público do banco
