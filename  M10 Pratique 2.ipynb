# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_renda = pd.read_csv('Profissão Cientista de Dados M10 A1.csv')
df_renda.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.pointplot(x='posse_de_veiculo', y='renda', data=df_renda, dodge=True, capsize=.1)
plt.title('Renda Média por Posse de Veículo')

plt.subplot(1, 2, 2)
sns.pointplot(x='posse_de_imovel', y='renda', data=df_renda, dodge=True, capsize=.1)
plt.title('Renda Média por Posse de Imóvel')

plt.tight_layout()
plt.show()

# %% [markdown]
# Entre as duas variáveis, a posse de veículo é a única que parece discriminar a renda de forma estatisticamente significante, porque, ao observar o gráfico de perfil de veículo, notei uma "escada" clara: os intervalos de confiança não se sobrepõem, o que me dá segurança de que a diferença de renda entre esses grupos é real. Já na posse de imóvel, identifiquei que os pontos estão em níveis muito próximos e as barras de erro quase se tocam, o que me indica que ter um imóvel não é um sinal tão forte ou garantido de uma renda maior. Portanto, eu considero a posse de veículo uma preditora muito melhor para o seu modelo.
